# %% [markdown]
# <a href="https://colab.research.google.com/github/Shobanaks/Amazon_sales_Data/blob/main/Amazon%20Data%20Analyzed%20file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dc2660d8-78d8-4011-881e-af40d7381616" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc2660d8-78d8-4011-881e-af40d7381616">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv(r"Amazon Sales data.csv")
df.head()
# Out:
#                  Country        Item Type Order Date     Order ID  \
# 0                 Tuvalu        Baby Food   28/05/10  669165933.0
# 1                Grenada           Cereal   22/08/12  963881480.0
# 2                 Russia  Office Supplies   2/5/2014  341417157.0
# 3  Sao Tome and Principe           Fruits   20/06/14  514321792.0
# 4                 Rwanda  Office Supplies   1/2/2013  115456712.0
#
#   Order Priority                             Region Sales Channel Ship Date  \
# 0           High              Australia and Oceania       Offline  27/06/10
# 1     CriticaLow  Central America and the Caribbean        Online  15/09/12
# 2            Low                             Europe       Offline  8/5/2014
# 3     CriticaLow                 Sub-Saharan Africa        Online  5/7/2014
# 4            Low                 Sub-Saharan Africa       Offline  6/2/2013
#
#    Total Cost  Total Revenue  Units Sold
# 0  1582243.50     2533654.00      9925.0
# ...

# %%
df['profit']=df['Total Revenue']-df['Total Cost']
df['profit']
# Out:
# 0       951410.50
# 1       248406.36
# 2       224598.75
# 3        19525.82
# 4       639077.50
#           ...
# 1712     65214.72
# 1713     15103.47
# 1714     93748.05
# 1715    144521.02
# 1716    889472.91
# Name: profit, Length: 1717, dtype: float64

# %%
df['Profit_Margin']=(df['profit']/df['Total Revenue'])*100
Profit_Margin
# Out:
# 0       37.550924
# 1       43.067574
# 2       19.386987
# 3       25.830654
# 4       19.386987
#           ...
# 1712    67.203514
# 1713    25.830654
# 1714    40.977541
# 1715    30.661936
# 1716    24.799856
# Length: 1717, dtype: float64

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df['Month']=df['Order Date'].dt.month_name()
print(df['Month'])
# Out:
# 0            May
# 1         August
# 2       February
# 3           June
# 4        January
#           ...
# 1712        July
# 1713    November
# 1714     January
# 1715        July
# 1716     October
# Name: Month, Length: 1717, dtype: object

# %%
df['Year']=df['Order Date'].dt.year
print(df['Year'])
# Out:
# 0       2010.0
# 1       2012.0
# 2       2014.0
# 3       2014.0
# 4       2013.0
#          ...
# 1712    2011.0
# 1713    2011.0
# 1714    2016.0
# 1715    2015.0
# 1716    2012.0
# Name: Year, Length: 1717, dtype: float64

# %%
df['Ship Date']=pd.to_datetime(df['Ship Date'])

# %%
df['Days_Took_To_Ship']=df['Ship Date']-df['Order Date']
print (df['Days_Took_To_Ship'])
# Out:
# 0        30 days
# 1        24 days
# 2       181 days
# 3       -44 days
# 4       151 days
#           ...
# 1712   -139 days
# 1713     47 days
# 1714    175 days
# 1715      9 days
# 1716   -230 days
# Name: Days_Took_To_Ship, Length: 1717, dtype: timedelta64[ns]

# %%
print(df)
# Out:
#                     Country        Item Type Order Date     Order ID  \
# 0                    Tuvalu        Baby Food 2010-05-28  669165933.0
# 1                   Grenada           Cereal 2012-08-22  963881480.0
# 2                    Russia  Office Supplies 2014-02-05  341417157.0
# 3     Sao Tome and Principe           Fruits 2014-06-20  514321792.0
# 4                    Rwanda  Office Supplies 2013-01-02  115456712.0
# ...                     ...              ...        ...          ...
# 1712                   Mali          Clothes 2011-07-26  512878119.0
# 1713               Malaysia           Fruits 2011-11-11  810711038.0
# 1714           Sierra Leone       Vegetables 2016-01-06  728815257.0
# 1715                 Mexico    Personal Care 2015-07-30  559427106.0
# 1716             Mozambique        Household 2012-10-02  665095412.0
#
#      Order Priority                             Region Sales Channel  \
# ...

# %%
df.to_csv('Amazon_final_data.csv', index=False)
from google.colab import files
files.download('Amazon_final_data.csv')
